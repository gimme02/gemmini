# %%
from driver import *
from ISA import *

# %%
Driver = driver()
datas = Driver.translate("tiled_matmul_ws_full-baremetal.txt", "tiled_matmul_ws_full-baremetal.trace")

# %%
datas
# Out:
# {'0x00000000': {'stage_info': {'ROB_ALLOC': 758045,
#    'ROB_ISSUE_EX': 758046,
#    'ENTER_EX_CTRL': 758046,
#    'ROB_COMPLETE': 758048,
#    'LEAVE_EX_CTRL': 758048},
#   'cmd_info': {'raw_cmd': ['14135419',
#     '4575657221408489476',
#     '281474976710656'],
#    'asm': {'inst': 'config_ex',
#     'act': 0,
#     'A_T': 0,
#     'B_T': 0,
#     'spad_stride': 1}}},
#  '0x00000001': {'stage_info': {'ROB_ALLOC': 758046,
#    'ROB_ISSUE_ST': 758047,
#    'ENTER_ST_CTRL': 758047,
#    'ST_CTRL_EXECUTE': 758048},
#   'cmd_info': {'raw_cmd': ['16167035', '2', '4575657221408424448'],
#    'asm': {'inst': 'config_mvout', 'dram_stride': 512}}},
#  '0x00000002': {'stage_info': {'ROB_ALLOC': 758047,
#    'ROB_ISSUE_LD': 758048,
#    'ENTER_LD_CTRL': 758048,
#    'LD_CTRL_EXECUTE': 758049},
#   'cmd_info': {'raw_cmd': ['16167035', '4575657221410521345', '128'],
#    'asm': {'inst': 'config_mvin0', 'spad_stride': 32, 'dram_stride': 128}}},
# ...

# %%
Driver.visualize(datas)

# %%
Driver.write("tiled_matmul_ws_full-baremetal.txt", datas)
# Out:
# 0x00000000
# 0x00000001
# 0x00000002
# 0x00000003
# 0x00000004
# 0x00000005
# 0x00000006
# 0x00000007
# 0x00000008
# 0x00000009
# 0x0000000a
# 0x0000000b
# 0x0000000c
# 0x0000000d
# 0x0000000e
# 0x0000000f
# 0x00000010
# 0x00000011
# 0x00000012
# 0x00000013
# 0x00000014
# 0x00000015
# 0x00000016
# 0x00000017
# 0x00000018
# 0x00000019
# 0x0000001a
# 0x0000001b
# 0x0000001c
# 0x0000001d
# 0x0000001e
# 0x0000001f
# 0x00000020
# 0x00000021
# 0x00000022
# 0x00000023
# 0x00000024
# 0x00000025
# 0x00000026
# 0x00000027
# 0x00000028
# 0x00000029
# 0x0000002a
# 0x0000002b
# 0x0000002c
# 0x0000002d
# 0x0000002e
# 0x0000002f
# 0x00000030
# 0x00000031
# 0x00000032
# 0x00000033
# 0x00000034
# 0x00000035
# 0x00000036
# 0x00000037
# 0x00000038
# 0x00000039
# 0x0000003a
# 0x0000003b
# 0x0000003c
# 0x0000003d
# 0x0000003e
# 0x0000003f
# 0x00000040
# 0x00000041
# 0x00000042
# 0x00000043
# 0x00000044
# 0x00000045
# 0x00000046
# 0x00000047
# 0x00000048
# 0x00000049
# 0x0000004a
# 0x0000004b
# ...
